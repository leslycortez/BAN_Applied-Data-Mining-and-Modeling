# %% [markdown]
# Support(A): Number if transactions in which the item A appears /Total number for transactions

# %% [markdown]
# Confidence (A => B): signifies the likelihood of the item B being purchase when item A is purchased

# %% [markdown]
# Conf(A,B) = support(A,B) / suporrt (A)

# %%
from mlxtend.preprocessing import TransactionEncoder

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# %%
import pandas as pd
data = pd.read_excel(r'C:\Users\pearl\Documents\BAN_Winter 2022\BAN230 - Data Mining\Market_Basket.xlsx')

# %%
data.head()
# Out:
#    Transaction ID  Wine  Chips  Bread  Milk
# 0               1     1      1      1     1
# 1               2     1      0      1     1
# 2               3     0      0      1     1
# 3               4     0      1      0     0
# 4               5     1      1      1     1

# %%
data.drop('Transaction ID', axis=1, inplace=True)

# %%
import pandas as pd
itemset = pd.DataFrame(data)

# %%
itemset
# Out:
#    Wine  Chips  Bread  Milk
# 0     1      1      1     1
# 1     1      0      1     1
# 2     0      0      1     1
# 3     0      1      0     0
# 4     1      1      1     1
# 5     1      1      0     1

# %%
freq_items = apriori(itemset, min_support=0.3, use_colnames=True)

# %%
freq_items
# Out:
#      support                    itemsets
# 0   0.666667                      (Wine)
# 1   0.666667                     (Chips)
# 2   0.666667                     (Bread)
# 3   0.833333                      (Milk)
# 4   0.500000               (Chips, Wine)
# 5   0.500000               (Wine, Bread)
# 6   0.666667                (Milk, Wine)
# 7   0.333333              (Chips, Bread)
# 8   0.500000               (Milk, Chips)
# 9   0.666667               (Milk, Bread)
# 10  0.333333        (Chips, Wine, Bread)
# 11  0.500000         (Milk, Chips, Wine)
# 12  0.500000         (Milk, Wine, Bread)
# 13  0.333333        (Milk, Chips, Bread)
# 14  0.333333  (Milk, Chips, Wine, Bread)

# %%
freq_items.sort_values(by='support')
# Out:
#      support                    itemsets
# 7   0.333333              (Chips, Bread)
# 10  0.333333        (Chips, Wine, Bread)
# 13  0.333333        (Milk, Chips, Bread)
# 14  0.333333  (Milk, Chips, Wine, Bread)
# 4   0.500000               (Chips, Wine)
# 5   0.500000               (Wine, Bread)
# 8   0.500000               (Milk, Chips)
# 11  0.500000         (Milk, Chips, Wine)
# 12  0.500000         (Milk, Wine, Bread)
# 0   0.666667                      (Wine)
# 1   0.666667                     (Chips)
# 2   0.666667                     (Bread)
# 6   0.666667                (Milk, Wine)
# 9   0.666667               (Milk, Bread)
# 3   0.833333                      (Milk)

# %%
rules = association_rules(freq_items, metric='confidence', min_threshold=1)

# %%
rules
# Out:
#             antecedents   consequents  antecedent support  consequent support  \
# 0                (Wine)        (Milk)            0.666667            0.833333
# 1               (Bread)        (Milk)            0.666667            0.833333
# 2        (Chips, Bread)        (Wine)            0.333333            0.666667
# 3         (Milk, Chips)        (Wine)            0.500000            0.666667
# 4         (Chips, Wine)        (Milk)            0.500000            0.833333
# 5         (Wine, Bread)        (Milk)            0.500000            0.833333
# 6        (Chips, Bread)        (Milk)            0.333333            0.833333
# 7  (Milk, Chips, Bread)        (Wine)            0.333333            0.666667
# 8  (Chips, Wine, Bread)        (Milk)            0.333333            0.833333
# 9        (Chips, Bread)  (Milk, Wine)            0.333333            0.666667
#
#     support  confidence  lift  leverage  conviction
# 0  0.666667         1.0   1.2  0.111111         inf
# 1  0.666667         1.0   1.2  0.111111         inf
# 2  0.333333         1.0   1.5  0.111111         inf
# 3  0.500000         1.0   1.5  0.166667         inf
# 4  0.500000         1.0   1.2  0.083333         inf
# 5  0.500000         1.0   1.2  0.083333         inf
# 6  0.333333         1.0   1.2  0.055556         inf
# 7  0.333333         1.0   1.5  0.111111         inf
# 8  0.333333         1.0   1.2  0.055556         inf
# 9  0.333333         1.0   1.5  0.111111         inf
